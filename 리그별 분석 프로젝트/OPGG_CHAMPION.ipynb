# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
# selenium을 백그라운드로 실행하기 위해 옵션 설정
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')

# %%
# 우리가 데이터를 가져올 웹 페이지입니다.
qwergg_url = 'https://www.op.gg/champion/statistics'

# selenium이 제어할 chrome을 실행합니다.
driver = webdriver.Chrome("C:/Users/LUNA/Desktop/OPGG/chromedriver_win32/chromedriver")
# driver = webdriver.Chrome("C:/Users/LUNA/Desktop/OPGG/chromedriver_win32/chromedriver", options= options)

# %%
# 데이터를 가져올 페이지로 이동합니다.
driver.get(qwergg_url)

# %%
lines = []
champion = []
rank     = []
win_rate = []
pick_rate = []

# %%
# 탑, 정글, 미드, 원딜, 서폿 클릭
for linenum in range(1,6):
    time.sleep(1)
    driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > ul > li:nth-child({linenum})').click()
    
    # 탑 일때
    if linenum ==1:
        aa =driver.find_elements_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-TOP > tr')
        for n in range(1, len(aa)+1):
            lines.append('TOP')
            champion.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-TOP > tr:nth-child({n}) > td:nth-child(4) > a > div:nth-child(1)').text.strip())
            rank.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-TOP > tr:nth-child({n}) > td:nth-child(1)').text.strip())
            win_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-TOP > tr:nth-child({n}) > td:nth-child(5)').text.strip())
            pick_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-TOP > tr:nth-child({n}) > td:nth-child(6)').text.strip())

    # 정글
    elif linenum ==2:
        aa =driver.find_elements_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-JUNGLE > tr')
        for n in range(1, len(aa)+1):
            lines.append('JUNGLE')
            champion.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-JUNGLE > tr:nth-child({n}) > td:nth-child(4) > a > div:nth-child(1)').text.strip())
            rank.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-JUNGLE > tr:nth-child({n}) > td:nth-child(1)').text.strip())
            win_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-JUNGLE > tr:nth-child({n}) > td:nth-child(5)').text.strip())
            pick_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-JUNGLE > tr:nth-child({n}) > td:nth-child(6)').text.strip())
# 미드
    elif linenum ==3:
        aa =driver.find_elements_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-MID > tr')
        for n in range(1, len(aa)+1):
            lines.append('MID')
            champion.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-MID > tr:nth-child({n}) > td:nth-child(4) > a > div:nth-child(1)').text.strip())
            rank.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-MID > tr:nth-child({n}) > td:nth-child(1)').text.strip())
            win_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-MID > tr:nth-child({n}) > td:nth-child(5)').text.strip())
            pick_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-MID > tr:nth-child({n}) > td:nth-child(6)').text.strip())
# 바텀
    elif linenum ==4:
        aa =driver.find_elements_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-ADC > tr')
        for n in range(1, len(aa)+1):
            lines.append('ADC')
            champion.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-ADC > tr:nth-child({n}) > td:nth-child(4) > a > div:nth-child(1)').text.strip())
            rank.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-ADC > tr:nth-child({n}) > td:nth-child(1)').text.strip())
            win_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-ADC > tr:nth-child({n}) > td:nth-child(5)').text.strip())
            pick_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-ADC > tr:nth-child({n}) > td:nth-child(6)').text.strip())


# 서포터
    elif linenum ==5:
        aa =driver.find_elements_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-SUPPORT > tr')
        for n in range(1, len(aa)+1):
            lines.append('SUPPORT')
            champion.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-SUPPORT > tr:nth-child({n}) > td:nth-child(4) > a > div:nth-child(1)').text.strip())
            rank.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-SUPPORT > tr:nth-child({n}) > td:nth-child(1)').text.strip())
            win_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-SUPPORT > tr:nth-child({n}) > td:nth-child(5)').text.strip())
            pick_rate.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-tier > div > table > tbody.tabItem.champion-trend-tier-SUPPORT > tr:nth-child({n}) > td:nth-child(6)').text.strip())

# %%
# DataFrame으로 변환 후 출력해봄
# 나중에 뒤로 옮겨야함
total_df = pd.DataFrame([lines,
                        champion,
                        rank,
                        win_rate,
                        pick_rate],
                               index = ['line','champion','rank','win_rate','pick_rate']).T
total_df
# Out:
#         line champion rank win_rate pick_rate
# 0        TOP      피오라    1   50.39%    11.42%
# 1        TOP       카밀    2   50.57%    12.21%
# 2        TOP       세트    3   50.80%    11.96%
# 3        TOP     탐 켄치    4   51.51%     4.47%
# 4        TOP     이렐리아    5   48.86%    12.45%
# ..       ...      ...  ...      ...       ...
# 211  SUPPORT      세라핀   38   47.61%     1.92%
# 212  SUPPORT      베이가   39   49.96%     0.75%
# 213  SUPPORT      벨코즈   40   48.44%     1.20%
# 214  SUPPORT     그라가스   41   48.68%     0.99%
# 215  SUPPORT       세트   42   44.34%     2.26%
#
# [216 rows x 5 columns]

# %%
total_df.to_csv('projectData/opgg_v1118.csv', encoding='cp949')

# %% [markdown]
# ## 벤률도 가져오자

# %%
a1 = driver.find_element_by_css_selector('body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-header > ul > li:nth-child(4)')
a1.click()

# %%
rank = []
champ = []
position = []
ban_rate = []

# %%
rank = driver.find_element_by_css_selector('body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-banratio > div > table > tbody.tabItem.champion-trend-banratio-ALL > tr:nth-child(1) > td:nth-child(1)')
champ = driver.find_element_by_css_selector('body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-banratio > div > table > tbody.tabItem.champion-trend-banratio-ALL > tr:nth-child(1) > td:nth-child(3) > a > div:nth-child(1) ')
position = driver.find_element_by_css_selector('body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-banratio > div > table > tbody.tabItem.champion-trend-banratio-ALL > tr:nth-child(1) > td:nth-child(3) > a > div:nth-child(2)')
ban_rate = driver.find_element_by_css_selector('body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-banratio > div > table > tbody.tabItem.champion-trend-banratio-ALL > tr:nth-child(1) > td:nth-child(4)')
# Out:
# '50.51%'

# %%
for i in range(1,156):
    rank.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-banratio > div > table > tbody.tabItem.champion-trend-banratio-ALL > tr:nth-child({i}) > td:nth-child(1)').text.strip())
    champ.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-banratio > div > table > tbody.tabItem.champion-trend-banratio-ALL > tr:nth-child({i}) > td:nth-child(3) > a > div:nth-child(1)').text.strip())
    position.append(driver.find_element_by_css_selector(f'body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-banratio > div > table > tbody.tabItem.champion-trend-banratio-ALL > tr:nth-child({i}) > td:nth-child(3) > a > div:nth-child(2)').text.strip())
    ban_rate.append(driver.find_element_by_css_selector('body > div.l-wrap.l-wrap--champion > div.l-container > div.l-champion-index > div.l-champion-index-content > div.l-champion-index-content--side > div > div.champion-index-trend-content > div > div.tabItem.champion-trend.champion-trend-banratio > div > table > tbody.tabItem.champion-trend-banratio-ALL > tr:nth-child(1) > td:nth-child(4)').text.strip())

# %%
# DataFrame으로 변환 후 출력해봄
# 나중에 뒤로 옮겨야함
total_df = pd.DataFrame([rank,
                        champ,
                        position,
                        ban_rate],
                               index = ['rank','champion','position','ban_rate']).T
total_df
# Out:
#     rank champion position ban_rate
# 0      1      리 신       정글   50.51%
# 1      2     이렐리아    탑, 미드   50.51%
# 2      3       제드   미드, 정글   50.51%
# 3      4      르블랑       미드   50.51%
# 4      5      사미라       바텀   50.51%
# ..   ...      ...      ...      ...
# 150  151      베이가  서포터, 미드   50.51%
# 151  152      코르키       미드   50.51%
# 152  153     세주아니       정글   50.51%
# 153  154       소나      서포터   50.51%
# 154  155      초가스        탑   50.51%
#
# [155 rows x 4 columns]

# %%
total_df.to_csv('projectData/opgg_v1118_ban.csv', encoding='cp949')
