# %%
import pandas as pd

# %%
LCS = pd.read_csv("projectData/LCS1.csv", index_col=0)

# %%
LCS[LCS['line'] == 'TOP'].groupby('champion').sum().sort_values('game', ascending=False).head(20)
# Out:
#           game  kill  death  assist   kda  win  lose   dpm
# champion
# 레넥톤         48  23.8   27.6    52.8  30.0   29    19  3861
# 나르          43  14.8   26.9    39.7  23.8   23    20  4207
# 그웬          37  28.6   26.9    37.4  29.6   21    16  4636
# 비에고         32  34.7   29.3    45.9  37.0   17    15  4236
# 갱플랭크        26  13.8   17.3    35.4  28.8   11    15  4291
# 리 신         23  11.8   26.8    37.8  18.8    6    17  3064
# 제이스         23  22.9   19.2    33.8  24.7   14     9  4178
# 세트          23  22.4   33.2    46.1  24.9   10    13  3367
# 카밀          16  34.0   19.9    46.9  38.5   13     3  3623
# 녹턴          14  14.0   20.9    21.5   9.9    7     7  1676
# 오른          12   3.8   11.7    20.3   9.9    5     7  1328
# 아칼리         10  37.2   26.0    34.7  34.6    5     5  4185
# 탐 켄치        10   2.8   13.0    29.3  18.2    5     5  1966
# 오공           7   6.8   17.8     8.8   3.7    1     6  1037
# 문도 박사        6   7.0   11.0    11.0   8.3    2     4  2360
# ...

# %%
LCS[LCS['line'] == 'JG'].groupby('champion').sum().sort_values('game', ascending=False).head(20)
# Out:
#           game  kill  death  assist   kda  win  lose   dpm
# champion
# 다이애나        61  39.9   33.3    92.8  54.3   41    20  5050
# 신 짜오        52  24.1   33.5    53.9  32.4   28    24  3393
# 리 신         48  35.0   32.4    78.9  50.2   26    22  3303
# 비에고         39  34.3   21.1    48.0  47.5   20    19  2778
# 럼블          34  39.4   29.5    69.5  46.3   14    20  5291
# 볼리베어        24  21.6   24.0    64.5  45.1   12    12  2606
# 올라프         15  23.6   11.8    25.8  48.0    8     7  2207
# 트런들         13   9.3   16.3    22.8  16.4    3    10  1126
# 그라가스        13  15.3   22.0    44.0  29.4    6     7  3261
# 우디르          9  11.0   11.3    29.0  29.8    5     4  1097
# 세주아니         7   8.7    8.0    22.0  11.9    4     3   921
# 녹턴           7  10.5   19.5    29.0  17.7    3     4  1363
# 그웬           5  14.0   13.0    19.0  13.2    1     4  1370
# 케인           5   6.5    5.0    11.0   7.3    2     3   691
# 바이           4   2.0    1.5     7.8   6.5    2     2   205
# ...

# %%
LCS[LCS['line'] == 'MID'].groupby('champion').sum().sort_values('game', ascending=False).head(10)
# Out:
#           game  kill  death  assist   kda  win  lose   dpm
# champion
# 루시안         38  39.3   30.4    54.1  35.4   23    15  5093
# 라이즈         34  25.4   28.5    41.9  25.4   20    14  3828
# 르블랑         34  37.5   23.0    39.7  52.5   20    14  5650
# 리 신         27  31.3   30.8    53.1  36.6   14    13  3695
# 오리아나        26  13.2   12.0    31.4  26.0   16    10  2764
# 신드라         22  23.4   20.7    39.5  33.6   11    11  4147
# 사일러스        22  28.1   25.6    44.6  28.5   10    12  3517
# 아지르         17  16.3   17.1    26.3  19.5    6    11  3720
# 아칼리         17  23.4   23.4    24.2  18.5    7    10  3251
# 비에고         15  17.5   16.3    35.5  35.5    5    10  2859

# %%
LCS[LCS['line'] == 'AD'].groupby('champion').sum().sort_values('game', ascending=False).head(10)
# Out:
#           game  kill  death  assist   kda  win  lose   dpm
# champion
# 바루스         67  30.7   27.0    53.0  40.9   34    33  6883
# 이즈리얼        51  41.1   22.3    59.3  59.4   24    27  8459
# 칼리스타        43  35.6   20.7    48.5  43.1   25    18  3632
# 아펠리오스       41  23.1   23.3    25.7  26.6   15    26  4437
# 트리스타나       38  36.3   27.4    51.7  45.8   24    14  5171
# 카이사         26  37.0   19.6    42.8  49.1   12    14  4320
# 직스          18  14.0   16.3    31.0  34.3    8    10  4842
# 진           12  24.5   13.0    47.5  55.5    7     5  3492
# 자야          11  18.5   19.5    32.5  25.2    5     6  3295
# 세나           9   9.3    5.2    32.0  46.5    7     2  1997

# %%
LCS[LCS['line'] == 'SUP'].groupby('champion').sum().sort_values('game', ascending=False).head(10)
# Out:
#           game  kill  death  assist   kda  win  lose   dpm
# champion
# 레오나         74   6.5   35.3    76.1  25.3   37    37  1060
# 노틸러스        56   7.4   28.4    78.9  33.6   31    25  1377
# 쓰레쉬         41   8.7   31.7    66.8  44.7   18    23  1032
# 라칸          36   5.5   21.1    83.9  55.3   18    18  1258
# 브라움         36   4.4   26.2    85.5  41.6   18    18  1440
# 알리스타        23   4.1   31.9    75.6  27.8   12    11  1065
# 렐           21   3.3   18.3    58.9  22.8   12     9   889
# 탐 켄치        17   4.2   22.0    40.5  21.3    7    10  1009
# 갈리오         10   2.5    7.0    34.1  28.6    7     3   639
# 세트          10   6.5   20.3    49.8  17.6    6     4  1165

# %%
LCS.groupby('champion').sum().sort_values('game', ascending=False).head(20)
# Out:
#           game  kill  death  assist    kda  win  lose    dpm
# champion
# 리 신         99  81.1   94.0   174.8  107.6   47    52  10343
# 비에고         86  86.5   66.7   129.4  120.0   42    44   9873
# 레오나         74   6.5   35.3    76.1   25.3   37    37   1060
# 바루스         67  30.7   27.0    53.0   40.9   34    33   6883
# 다이애나        61  39.9   33.3    92.8   54.3   41    20   5050
# 노틸러스        56   7.4   28.4    78.9   33.6   31    25   1377
# 레넥톤         52  25.3   39.6    62.3   33.1   29    23   4642
# 신 짜오        52  24.1   33.5    53.9   32.4   28    24   3393
# 이즈리얼        52  45.1   24.3    63.3   63.4   24    28   9045
# 트리스타나       49  57.8   39.3    77.4   76.3   28    21   8297
# 칼리스타        45  49.6   26.7    61.5   59.0   27    18   4672
# 나르          43  14.8   26.9    39.7   23.8   23    20   4207
# 그웬          42  42.6   39.9    56.4   42.8   22    20   6006
# 쓰레쉬         41   8.7   31.7    66.8   44.7   18    23   1032
# ...

# %%
LCS[LCS['champion'] == '나르']
# Out:
#        call_name               player_name line champion  game  win_rate  \
# 4     TL Alphari   Barney Morris1999.10.20  TOP       나르     3      33.3
# 9    100 Ssumday             김찬호1996.07.03  TOP       나르    10      70.0
# 21     EG Impact             정언영1995.03.07  TOP       나르     7      42.9
# 45      C9 Fudge  إبراهيم اللامي2002.05.23  TOP       나르     6      83.3
# 59      TSM Huni             허승훈1997.12.25  TOP       나르     4      75.0
# 102  GG Licorice    Eric Ritchie1997.09.30  TOP       나르     1       0.0
# 108      GG Solo   Colin Earnest1993.05.26  TOP       나르     3      33.3
# 116  DIG FakeGod       Aaron Lee2000.05.27  TOP       나르     8      37.5
# 131     FLY Kumo      Colin Zhao2000.03.09  TOP       나르     1       0.0
#
#      kill  death  assist  kda  win  lose  dpm
# 4     1.3    1.3     4.7  4.5    1     2  424
# 9     1.9    1.8     5.0  3.8    7     3  474
# 21    2.0    3.4     4.9  2.0    3     4  440
# 45    2.2    1.7     6.2  5.0    5     1  432
# ...

# %%
LCS['win_rate'] = LCS['win_rate'].str.replace('%',' ')
LCS['win_rate'] = pd.to_numeric(LCS['win_rate'])

# %%
LCS[LCS['champion'] == '신 짜오'].sum()
# Out:
# call_name      C9 BlaberTSM SpicaDIG Dardoch100 CloserIMT Xer...
# player_name    Robert Huang2000.01.04Mingyi Lu2001.02.17Joshu...
# line                                      JGJGJGJGJGJGJGJGJGJGJG
# champion            신 짜오신 짜오신 짜오신 짜오신 짜오신 짜오신 짜오신 짜오신 짜오신 짜오신 짜오
# game                                                          52
# win_rate                                                   452.6
# kill                                                        24.1
# death                                                       33.5
# assist                                                      53.9
# kda                                                         32.4
# win                                                           28
# lose                                                          24
# dpm                                                         3393
# dtype: object

# %% [markdown]
# # LCS 리그 특징

# %% [markdown]
# ## 단판경기
#
# 리그경기가 단판으로 이루어짐<BR>
# </BR>
#
# <PRE>
#
# 2014 시즌부터 LCS는 꾸준히 롤드컵에 진출하고 있음 -> 7년의 롤드컵 진출기록
# 그중 8강 진출에 성공한 시즌은 4번 성공했음
#
# 그 중 서머시즌이 다전제로 진행되었던 시즌이 두시즌이며 그 시즌에는 롤드컵 8강진출에 모두 성공했음
# 2/2
#
# 나머지는 모두 단판경기로 리그가 진행 되었으며 단판경기 시즌의 경우 5번의 도전에서 2번만 8강진출에 성공함
# 2/5
#
# 특히 최근 2시즌은 단일세트로 진행되었는데 8강은 모두 진출 실패했음
#
# 메타, 폼 등의 다양한 확인을 해봐야하겠지만
#      다전제 도입도 다시 한번쯤 시도해볼만하지 않을까 생각함
# </PRE>
#
# ## 다양한 챔피언 활용
#
# <PRE>
# LEC : 90
# LCS : 135
# LCK : 226
# LPL : 328
#
# 메이저 리그중 경기수가 135 경기로 적지만 103개로 가장 많은 챔피언이 밴픽에 등장한 리그임
# 뭔가 새로운 픽의 도전이 많은거같은데 그런거 치고는 조커픽들은 거의 다 패배함
# </PRE>

# %% [markdown]
# <pre>
# 리그에서 가장 많이 사용된 챔피언은 리 신, 비에고, 레오나, 바루스, 다이애나임
# 아무래도 LCK와 비슷하게 라인 스왑이 가능한 픽, 성능 좋은 픽을 선호하며 리신과 비에고가 라인에 섰을 때 다이애나라는 AP정글픽을 선택했을 듯
#
# 리 신
#     JG : 48
#     MID : 27
#     TOP : 23
#     AD  : 1
#     원딜로 시도된 경기도 한경기 있는데 어떤 시도인지 확인해봐야할 듯
#
# 비에고
#     JG : 39
#     MID : 15
#     TOP : 32
#
# 리신, 비에고 모두 상체 모든라인에서 사용하는 것을 알 수 있음
#
# 다이애나를 제외하면 픽 순 상위 픽에 AP 비율이 떨어짐
# 미드에서 확실한 AP를 가져오는 방식으로 플레이 할 것으로 예상됨
# 전체적인 픽의 형태로 보았을 때 LCK와 유사하다고 생각함
#
# 밴픽으로 나온 챔피언은 모두 103개
# 밴이 가장 많이된 챔피언은 신짜오, 쓰레쉬, 그웬 순서
#
# 밴픽 모두로 보았을 때
# 신짜오, 리신, 비에고, 그웬, 쓰레쉬, 레넥톤,레오나, 칼리스타, 바루스 순서
# 루시안은 생각보다 그렇게 견제받지 않았고 그만큼 나온느낌
#
#
# 신짜오 견제가 많이되서 그만큼 못나온 느낌..?
# 나왔을때 승률은 53% 인데 압도적으로 승률이 높은 선수 몇명이있음
# </pre>
#
#
# # 북미잼
# ## 운0의 리그라는 평이 있음
# ### 레드 우세
# ![image.png](attachment:image.png)
#
# LCS의 경우 : 대부분의 지표가 레드팀에서 좋은 모습
#
# 첫전령과 첫타워는 함께 연결되는 경우가 많음<BR>
# 근데 전령은 블루가 더먹는데 레드가 오히려 첫타워를 더 많이부숨<BR>
# 이해가 안되는데 생각할 수 있는 가능성은 상대가 전령칠때 바텀에서 합류없이 타워부수는거
#     근데 그런거치고는 또 전령 획득률이 다른리그보다 낮음
#
# ![image-2.png](attachment:image-2.png)
#         (LCK)
#     ![image-3.png](attachment:image-3.png)
#         (LEC)
#     <pre> 레드팀과 블루팀의 전령, 드래곤 갈라먹기가 극명하게 나타남
# 그에 비해 LCS 팀들은 블루팀의 전령 획득 능력이 떨어지는 것같음
#
# 개인적인 생각이지만 전령 싸움에 대한 블루팀의 장점을 활용하는 능력이 LCK에 비해 부족하고
# 블루팀에서 전령을 획득해도 이후 전령을 이용한 스노우볼 능력이 부족해 드래곤을 먼저먹게되는 레드팀에게 끌려가는 형태가 아닐까
# 바론 대 드래곤의 상황에서 드래곤의 선택을 강제당하게 되는 것아닐까
# </pre>

# %% [markdown]
# ### TOP
# <PRE>
# 레넥톤, 나르, 그웬 순으로 자주 사용함
# 먼저 뽑기 무난한 픽으로 많이 가져왔을 것으로 추측됨
#
# TOP 10개의 픽 중 주 역활군이 탱커인 챔피언이 진짜 하나도없음
# 물론 당시 메타의 영향도 있을거고 탱커의 영향력이 적은 시즌이기에 그런 듯
#
# TOP 10의 픽중 유일한 AP가 그웬인 만큼 정글,미드에서 확실한 AP딜러를 사용할 확률이 높아보임
#
# 제이스 선호도가 조금 떨어지는 듯한 모습인데
# 밴도 21번되었음 => 그냥 선호도 자체가 떨어지는 듯함
#
# 케넨에 대한 관심은 전혀 없는 듯
# LCK의 경우 나르의 탑 픽률이 1위인 만큼 나르 상대로 라인전을 주도할 수 있는 케넨이라는 픽이 연구되어 나왔다는 느낌이라면
# LCS는 나르에 대한 대응책으로 다른 카드들을 사용했을 가능성이 높아보임
# </PRE>
#
#
# ### JG
# 예상외로 다이애나가 1순위 픽을 가지고있음
# 그 뒤로 신짜오, 리신, 비에고 럼블 순임
#
# LCK랑 진짜 비슷함
# 차이를 확인해보자면 니달리를 사용하지않는다

# %% [markdown]
# # 비교용 LCK

# %%
LCK = pd.read_csv("projectData/LCK_FULL.csv", index_col=0)

# %%
LCK[LCK['champion'] == '루시안'].groupby('champion').sum().sort_values('game', ascending=False).head(20)
# Out:
#           game  kill  death  assist   kda  win  lose   dpm
# champion
# 루시안         42  39.3   26.1    59.4  45.6   19    23  5804

# %%
LCK[LCK['champion'] == '루시안']
# Out:
#         call_name    player_name line champion  game win_rate  kill  death  \
# 36        AF Kiin  김기인1999.05.28  TOP      루시안     2    50.0%   0.0    2.0
# 203  DK ShowMaker   허수2000.07.22  MID      루시안     7    57.1%   3.3    2.1
# 239       KT Dove  김재연1998.07.25  MID      루시안     6    33.3%   5.0    2.3
# 252      BRO Lava  김태훈1999.07.14  MID      루시안     5    60.0%   4.8    1.8
# 271       GEN Bdd  곽보성1999.03.01  MID      루시안     1       0%   3.0    2.0
# 303     DRX SOLKA  송수형2002.08.25  MID      루시안     1       0%   0.0    1.0
# 6        T1 Canna  김창동2000.02.11  TOP      루시안     4    25.0%   2.5    3.0
# 108     HLE Chovy  정지훈2001.03.03  MID      루시안     1   100.0%   8.0    2.0
# 115      LSB FATE  유수혁2000.08.22  MID      루시안    10    40.0%   2.0    1.9
# 142      T1 Faker  이상혁1996.05.07  MID      루시안     1       0%   2.0    4.0
# 152       NS Gori  김태우2000.08.09  MID      루시안     3    66.7%   3.7    2.0
# ...

# %%
LCK['win_rate'] = LCK['win_rate'].str.replace('%',' ')
LCK['win_rate'] = pd.to_numeric(LCK['win_rate'])

# %%
LCK[LCK['champion'] == '루시안']
# Out:
#         call_name    player_name line champion  game  win_rate  kill  death  \
# 36        AF Kiin  김기인1999.05.28  TOP      루시안     2      50.0   0.0    2.0
# 203  DK ShowMaker   허수2000.07.22  MID      루시안     7      57.1   3.3    2.1
# 239       KT Dove  김재연1998.07.25  MID      루시안     6      33.3   5.0    2.3
# 252      BRO Lava  김태훈1999.07.14  MID      루시안     5      60.0   4.8    1.8
# 271       GEN Bdd  곽보성1999.03.01  MID      루시안     1       0.0   3.0    2.0
# 303     DRX SOLKA  송수형2002.08.25  MID      루시안     1       0.0   0.0    1.0
# 6        T1 Canna  김창동2000.02.11  TOP      루시안     4      25.0   2.5    3.0
# 108     HLE Chovy  정지훈2001.03.03  MID      루시안     1     100.0   8.0    2.0
# 115      LSB FATE  유수혁2000.08.22  MID      루시안    10      40.0   2.0    1.9
# 142      T1 Faker  이상혁1996.05.07  MID      루시안     1       0.0   2.0    4.0
# 152       NS Gori  김태우2000.08.09  MID      루시안     3      66.7   3.7    2.0
# ...

# %% [markdown]
# ##  리그별 특징
#
#
# ### 챔피언- > 라인별로 어떤 챔피언이 쓰인다  민정
#
# ## 뭐가 많이 나왔다
# ## 메타 챔프 사용 여부
# ### 근거가 있어야한다.
#
#
#
# # 경기 결과 데이터 가져오기
#
#
# ### 교전이많다. 게임이 빠르다, 오브젝트에 관심도
#
# ## 게임이 진행되는 과정에서 역전이 몇번되는가
#
# ## 골드 역전확인하기
#
# ## 게임시간에비해 킬수가 많으면 싸움이 많다
#
# ##
