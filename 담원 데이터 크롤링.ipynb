# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
# selenium을 백그라운드로 실행하기 위해 옵션 설정
options = webdriver.ChromeOptions()
# options.add_argument('headless')
options.add_argument('--start-fullscreen')
# options.add_argument('window-size=1920x1080')

# %%
# 우리가 데이터를 가져올 웹 페이지입니다.
league_data_url = 'https://gol.gg/teams/team-matchlist/1092/split-ALL/tournament-LCK%20Spring%202021/'

# %%
# selenium이 제어할 chrome을 실행합니다.
# driver = webdriver.Chrome("C:/Users/LUNA/Desktop/OPGG/chromedriver_win32/chromedriver")
driver = webdriver.Chrome("C:/Users/LUNA/Desktop/OPGG/chromedriver_win32/chromedriver", options= options)

# %%
# 데이터를 가져올 페이지로 이동합니다.
driver.get(league_data_url)

# %%
# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []
call_name     = []
kill          = []
death         = []
assist        = []
kda           = []
cs            = []
csinteamjg    = []
csinenemyjg   = []
csm           = []
golds         = []
gpm           = []
gold_per      = []
visionscore   = []
ward_placed   = []
ward_destroyed= []
vspm          = []
wpm           = []
vwpm          = []
wcpm          = []
vs_per        = []
Total_damage  = []
dpm           = []
dmg_per       = []
gd15          = []
csd15         = []
xpd15         = []
lvld15        = []
to_dmg_turrets= []
champion      = []

# %%
# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td.text-center.footable-visible.footable-last-column').click()
    time.sleep(1)
    
    # 요약본에서 정보 가져오기
    gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
    blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
    blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
    red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
    red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
    client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
    
    ## All stat 들어가서 상세 정보 가져오기
    driver.find_element_by_css_selector('#gameMenu2Toggler > ul > li:nth-child(2) > a').click()
    
    
    driver.back()
    time.sleep(1)
    
    driver.back()
    time.sleep(1)

# %%
total_df = pd.DataFrame([gametime,
                         blue_teamname,
                         blue_result,
                         red_teamname,
                         red_result,
                        client_version],
                        index = ['gametime','blue_teamname','blue_result','red_teamname','red_result','client_version']).T

# %%
total_df.to_csv('DK Game.csv')

# %%
total_df

# %%
a= driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right')
a.get_attribute('innerHTML')

# %%
b =  driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div')

# %%
b.text.strip()[-4:]

# %%
#table-1339 > thead > tr > th:nth-child(2) > img

# %%
for i in range(2,12):
    c = driver.find_elements_by_css_selector(f'body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table >thead > tr > th:nth-child({i}) > img ')
    for i2 in c:
        print(i2.get_attribute('alt'))

# %%
d = driver.find_element_by_css_selector("body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(1) > td:nth-child(2)").text.strip()

# %%
print(d)

# %% [markdown]
# # 이제 상세정보 추가할거임

# %%
# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    for num in range(2, 12):
    # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
    
    ## All stat 들어가서 상세 정보 가져오기
    time.sleep(1)
    driver.find_element_by_css_selector('#gameMenu2Toggler > ul > li:nth-child(2) > a').click()
    
    time.sleep(1)
    for num3 in range(2,12):
        c = driver.find_elements_by_css_selector(f'body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table >thead > tr > th:nth-child({num3}) > img ')
        for i2 in c:
            champion.append(i2.get_attribute('alt'))
            
    # 상세 정보들 각 리스트에 넣어주기
    for num2 in range(2, 12):
        call_name.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(1) > td:nth-child({num2})").text.strip())
        kill.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(3) > td:nth-child({num2})").text.strip())
        death.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(4) > td:nth-child({num2})").text.strip())
        assist.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(5) > td:nth-child({num2})").text.strip())
        kda.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(6) > td:nth-child({num2})").text.strip())
        cs.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(7) > td:nth-child({num2})").text.strip())
        csinteamjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(8) > td:nth-child({num2})").text.strip())
        csinenemyjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(9) > td:nth-child({num2})").text.strip())
        csm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(10) > td:nth-child({num2})").text.strip())
        golds.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(11) > td:nth-child({num2})").text.strip())
        gpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(12) > td:nth-child({num2})").text.strip())
        gold_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(13) > td:nth-child({num2})").text.strip())
        ward_placed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(14) > td:nth-child({num2})").text.strip())
        ward_destroyed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(15) > td:nth-child({num2})").text.strip())
        vspm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(16) > td:nth-child({num2})").text.strip())
        wpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(18) > td:nth-child({num2})").text.strip())
        vwpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(19) > td:nth-child({num2})").text.strip())
        wcpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(20) > td:nth-child({num2})").text.strip())
        vs_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(21) > td:nth-child({num2})").text.strip())
        Total_damage.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(22) > td:nth-child({num2})").text.strip())
        dpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(27) > td:nth-child({num2})").text.strip())
        dmg_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(28) > td:nth-child({num2})").text.strip())
        gd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(36) > td:nth-child({num2})").text.strip())
        csd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(37) > td:nth-child({num2})").text.strip())
        xpd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(38) > td:nth-child({num2})").text.strip())
        lvld15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(39) > td:nth-child({num2})").text.strip())
        to_dmg_turrets.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(40) > td:nth-child({num2})").text.strip())

    

    
    time.sleep(1)
    
    
    driver.back()
    time.sleep(1)
    
    driver.back()
    time.sleep(1)

# %%
# 데이터를 가져올 페이지로 이동합니다.
driver.get(league_data_url2)

# %%
# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    for num in range(2, 12):
    # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
    
    ## All stat 들어가서 상세 정보 가져오기
    time.sleep(1)
    driver.find_element_by_css_selector('#gameMenu2Toggler > ul > li:nth-child(2) > a').click()
    
    time.sleep(1)
    for num3 in range(2,12):
        c = driver.find_elements_by_css_selector(f'body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table >thead > tr > th:nth-child({num3}) > img ')
        for i2 in c:
            champion.append(i2.get_attribute('alt'))
            
            
    for num2 in range(2, 12):
        call_name.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(1) > td:nth-child({num2})").text.strip())
        kill.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(3) > td:nth-child({num2})").text.strip())
        death.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(4) > td:nth-child({num2})").text.strip())
        assist.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(5) > td:nth-child({num2})").text.strip())
        kda.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(6) > td:nth-child({num2})").text.strip())
        cs.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(7) > td:nth-child({num2})").text.strip())
        csinteamjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(8) > td:nth-child({num2})").text.strip())
        csinenemyjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(9) > td:nth-child({num2})").text.strip())
        csm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(10) > td:nth-child({num2})").text.strip())
        golds.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(11) > td:nth-child({num2})").text.strip())
        gpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(12) > td:nth-child({num2})").text.strip())
        gold_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(13) > td:nth-child({num2})").text.strip())
        ward_placed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(14) > td:nth-child({num2})").text.strip())
        ward_destroyed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(15) > td:nth-child({num2})").text.strip())
        vspm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(16) > td:nth-child({num2})").text.strip())
        wpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(18) > td:nth-child({num2})").text.strip())
        vwpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(19) > td:nth-child({num2})").text.strip())
        wcpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(20) > td:nth-child({num2})").text.strip())
        vs_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(21) > td:nth-child({num2})").text.strip())
        Total_damage.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(22) > td:nth-child({num2})").text.strip())
        dpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(27) > td:nth-child({num2})").text.strip())
        dmg_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(28) > td:nth-child({num2})").text.strip())
        gd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(36) > td:nth-child({num2})").text.strip())
        csd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(37) > td:nth-child({num2})").text.strip())
        xpd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(38) > td:nth-child({num2})").text.strip())
        lvld15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(39) > td:nth-child({num2})").text.strip())
        to_dmg_turrets.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(40) > td:nth-child({num2})").text.strip())

    

    
    time.sleep(1)
    
    
    driver.back()
    time.sleep(1)
    
    driver.back()
    time.sleep(1)

# %%
total_df = pd.DataFrame([gametime,
                         blue_teamname,
                         blue_result,
                         red_teamname,
                         red_result,
                        client_version,
                        call_name,
                         champion,
                        kill,
                        death,
                        assist,
                        kda,
                        cs,
                        csinteamjg,
                        csinenemyjg,
                        csm,
                        golds,
                        gpm,
                        gold_per,
                        ward_placed,
                        ward_destroyed,
                        vspm,
                        wpm,
                        vwpm,
                        wcpm,
                        vs_per,
                        Total_damage,
                        dpm,
                        dmg_per,
                        gd15,
                        csd15,
                        xpd15,
                        lvld15,
                        to_dmg_turrets],
                        index = ['gametime','blue_teamname','blue_result','red_teamname','red_result','client_version','call_name','champion',
                                'kill','death','assist','kda','cs',"csinteamjg","csinenemyjg",
                        "csm",
                        "golds",
                        "gpm",
                        "gold_per",
                        "ward_placed",
                        "ward_destroyed",
                        "vspm",
                        "wpm",
                        "vwpm",
                        "wcpm",
                        "vs_per",
                        "Total_damage",
                        "dpm",
                        "dmg_per",
                        "gd15",
                        "csd15",
                        "xpd15",
                        "lvld15",
                        "to_dmg_turrets"]).T

# %%
total_df

# %%
total_df.to_csv('DKGAMEDATA_PS.csv')

# %%
# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []

blue_kill     = []
blue_turret   = []
blue_dragon   = []
blue_baron    = []
blue_gold     = []
blue_bans      = []
blue_picks     = []

red_kill      = []
red_turret    = []
red_dragon    = []
red_baron     = []
red_gold      = []
red_bans       = []
red_picks      = []

# %%
# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    blue_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    blue_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')

    red_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    red_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')
    
    for i in blue_ban:
        blue_bans.append(i.get_attribute('title'))
    for i2 in blue_pick:
        blue_picks.append(i2.get_attribute('title'))
    for i3 in red_ban:
        red_bans.append(i3.get_attribute('title'))
    for i4 in red_pick:
        red_picks.append(i4.get_attribute('title'))


        # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
       # 블루팀 정보
        blue_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        blue_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        blue_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        blue_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        blue_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(5) > span').text.strip())

        # 레드팀 정보
        red_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        red_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        red_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        red_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        red_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(5) > span').text.strip())
    
    driver.back()
    time.sleep(1)

# %%
total_df = pd.DataFrame([blue_teamname,
                        red_teamname,
                        gametime,
                        client_version,
                        blue_result,
                        red_result,
                        blue_kill,
                        blue_turret,
                        blue_dragon,
                        blue_baron,
                        blue_gold,
                        red_kill,
                        red_turret,
                        red_dragon,
                        red_baron,
                        red_gold],
                        index = ['blue_teamname',
                        'red_teamname',
                        'gametime',
                        'client_version',
                        'blue_result',
                        'red_result',
                        'blue_kill',
                        'blue_turret',
                        'blue_dragon',
                        'blue_baron',
                        'blue_gold',
                        'red_kill',
                        'red_turret',
                        'red_dragon',
                        'red_baron',
                        'red_gold']).T

# %%
total_df.to_csv('DKgameSummary.csv')

# %%
driver.quit()

# %%
total_df = pd.DataFrame([client_version,
                        blue_teamname,
                         blue_result,
                        red_teamname,
                         red_result,
                        gametime,
                        # 블루팀
                        blue_bans,
                        blue_picks,
                        blue_kill,
                        blue_turret,
                        blue_dragon,
                        blue_baron,
                        blue_gold,
                        # 레드팀
                        red_bans,
                        red_picks,
                        red_kill,
                        red_turret,
                        red_dragon,
                        red_baron,
                        red_gold],
                        index = ['client_version',
                        'blue_teamname',
                         'blue_result',
                        'red_teamname',
                         'red_result',
                        'gametime',
                        # 블루팀
                        'blue_bans',
                        'blue_picks',
                        'blue_kill',
                        'blue_turret',
                        'blue_dragon',
                        'blue_baron',
                        'blue_gold',
                        # 레드팀
                        'red_bans',
                        'red_picks',
                        'red_kill',
                        'red_turret',
                        'red_dragon',
                        'red_baron',
                        'red_gold']).T

# %%
total_df.to_csv('DKgameSummary_PS.csv')

# %%
total_df.to_csv('DKgameSummary.csv')

# %%
total_df['red_bans'] = total_df['red_bans'].str.replace('stats','')
total_df['red_bans'] = total_df['red_bans'].str.replace(' ','')

# %%
total_df['red_bans'] = total_df['red_bans'].str.replace('stats','')
total_df['red_bans'] = total_df['red_bans'].str.replace(' ','')
total_df['red_picks'] = total_df['red_picks'].str.replace('stats','')
total_df['red_picks'] = total_df['red_picks'].str.replace(' ','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace('stats','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace(' ','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace('stats','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace(' ','')

# %%
total_df.to_csv('DKgameSummary2.csv')

# %%
a = total_df[total_df['blue_teamname'] == 'DWG KIA'][['red_bans']]
b = total_df[total_df['red_teamname'] == 'DWG KIA'][['blue_bans']]

# %% [markdown]
# ## 젠지 데이터도 확인

# %%
# 우리가 데이터를 가져올 웹 페이지입니다.
league_data_url = 'https://gol.gg/teams/team-matchlist/1126/split-ALL/tournament-LCK%20Spring%202021/'
league_data_url2 = 'https://gol.gg/teams/team-matchlist/1126/split-ALL/tournament-LCK%20Spring%20Playoffs%202021/'

# %%
# selenium이 제어할 chrome을 실행합니다.
# driver = webdriver.Chrome("C:/Users/LUNA/Desktop/OPGG/chromedriver_win32/chromedriver")
driver = webdriver.Chrome("C:/Users/LUNA/Desktop/OPGG/chromedriver_win32/chromedriver", options= options)

# %%
# 데이터를 가져올 페이지로 이동합니다.
driver.get(league_data_url)

# %%
# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []
call_name     = []
kill          = []
death         = []
assist        = []
kda           = []
cs            = []
csinteamjg    = []
csinenemyjg   = []
csm           = []
golds         = []
gpm           = []
gold_per      = []
visionscore   = []
ward_placed   = []
ward_destroyed= []
vspm          = []
wpm           = []
vwpm          = []
wcpm          = []
vs_per        = []
Total_damage  = []
dpm           = []
dmg_per       = []
gd15          = []
csd15         = []
xpd15         = []
lvld15        = []
to_dmg_turrets= []
champion      = []

# %%
# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    for num in range(2, 12):
    # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
    
    ## All stat 들어가서 상세 정보 가져오기
    time.sleep(1)
    driver.find_element_by_css_selector('#gameMenu2Toggler > ul > li:nth-child(2) > a').click()
    
    time.sleep(1)
    for num3 in range(2,12):
        c = driver.find_elements_by_css_selector(f'body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table >thead > tr > th:nth-child({num3}) > img ')
        for i2 in c:
            champion.append(i2.get_attribute('alt'))
            
            
    for num2 in range(2, 12):
        call_name.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(1) > td:nth-child({num2})").text.strip())
        
        kill.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(3) > td:nth-child({num2})").text.strip())
        death.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(4) > td:nth-child({num2})").text.strip())
        assist.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(5) > td:nth-child({num2})").text.strip())
        kda.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(6) > td:nth-child({num2})").text.strip())
        cs.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(7) > td:nth-child({num2})").text.strip())
        csinteamjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(8) > td:nth-child({num2})").text.strip())
        csinenemyjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(9) > td:nth-child({num2})").text.strip())
        csm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(10) > td:nth-child({num2})").text.strip())
        golds.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(11) > td:nth-child({num2})").text.strip())
        gpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(12) > td:nth-child({num2})").text.strip())
        gold_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(13) > td:nth-child({num2})").text.strip())
        visionscore.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(14) > td:nth-child({num2})").text.strip())
        ward_placed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(15) > td:nth-child({num2})").text.strip())
        ward_destroyed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(16) > td:nth-child({num2})").text.strip())
        
        vspm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(18) > td:nth-child({num2})").text.strip())
        wpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(19) > td:nth-child({num2})").text.strip())
        vwpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(20) > td:nth-child({num2})").text.strip())
        wcpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(21) > td:nth-child({num2})").text.strip())
        vs_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(22) > td:nth-child({num2})").text.strip())
        Total_damage.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(23) > td:nth-child({num2})").text.strip())
        
        dpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(27) > td:nth-child({num2})").text.strip())
        dmg_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(28) > td:nth-child({num2})").text.strip())
        gd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(36) > td:nth-child({num2})").text.strip())
        csd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(37) > td:nth-child({num2})").text.strip())
        xpd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(38) > td:nth-child({num2})").text.strip())
        lvld15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(39) > td:nth-child({num2})").text.strip())
        to_dmg_turrets.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(40) > td:nth-child({num2})").text.strip())

    

    
    time.sleep(1)
    
    
    driver.back()
    time.sleep(1)
    
    driver.back()
    time.sleep(1)

# %%
total_df = pd.DataFrame([client_version,
                         gametime,
                            blue_teamname,
                            blue_result,
                         red_teamname,
                         red_result,
                            call_name,
                             champion,
                            kill,
                            death,
                            assist,
                            kda,
                            cs,
                            csinteamjg,
                            csinenemyjg,
                            csm,
                            golds,
                            gpm,
                            gold_per,
                            visionscore,
                            ward_placed,
                            ward_destroyed,
                            vspm,
                            wpm,
                            vwpm,
                            wcpm,
                            vs_per,
                            Total_damage,
                            dpm,
                            dmg_per,
                            gd15,
                            csd15,
                            xpd15,
                            lvld15,
                            to_dmg_turrets],
                        index = ['client_version',
                         'gametime',
                            'blue_teamname',
                            'blue_result',
                         'red_teamname',
                         'red_result',
                            'call_name',
                            'kill',
                            'death',
                            'assist',
                            'kda',
                            'cs',
                            'csinteamjg',
                            'csinenemyjg',
                            'csm',
                            'golds',
                            'gpm',
                            'gold_per',
                            'visionscore',
                            'ward_placed',
                            'ward_destroyed',
                            'vspm',
                            'wpm',
                            'vwpm',
                            'wcpm',
                            'vs_per',
                            'Total_damage',
                            'dpm',
                            'dmg_per',
                            'gd15',
                            'csd15',
                            'xpd15',
                            'lvld15',
                            'to_dmg_turrets']).T

# %%
total_df.to_csv('GengData.csv')

# %% [markdown]
# ## summary

# %%
# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []

blue_kill     = []
blue_turret   = []
blue_dragon   = []
blue_baron    = []
blue_gold     = []
blue_bans      = []
blue_picks     = []

red_kill      = []
red_turret    = []
red_dragon    = []
red_baron     = []
red_gold      = []
red_bans       = []
red_picks      = []

# %%
# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    blue_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    blue_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')

    red_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    red_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')
    
    for i in blue_ban:
        blue_bans.append(i.get_attribute('title'))
    for i2 in blue_pick:
        blue_picks.append(i2.get_attribute('title'))
    for i3 in red_ban:
        red_bans.append(i3.get_attribute('title'))
    for i4 in red_pick:
        red_picks.append(i4.get_attribute('title'))


        # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
       # 블루팀 정보
        blue_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        blue_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        blue_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        blue_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        blue_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(5) > span').text.strip())

        # 레드팀 정보
        red_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        red_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        red_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        red_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        red_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(5) > span').text.strip())
    
    driver.back()
    time.sleep(1)

# %%
total_df = pd.DataFrame([client_version,
                        blue_teamname,
                         blue_result,
                        red_teamname,
                         red_result,
                        gametime,
                        # 블루팀
                        blue_bans,
                        blue_picks,
                        blue_kill,
                        blue_turret,
                        blue_dragon,
                        blue_baron,
                        blue_gold,
                        # 레드팀
                        red_bans,
                        red_picks,
                        red_kill,
                        red_turret,
                        red_dragon,
                        red_baron,
                        red_gold],
                        index = ['client_version',
                        'blue_teamname',
                         'blue_result',
                        'red_teamname',
                         'red_result',
                        'gametime',
                        # 블루팀
                        'blue_bans',
                        'blue_picks',
                        'blue_kill',
                        'blue_turret',
                        'blue_dragon',
                        'blue_baron',
                        'blue_gold',
                        # 레드팀
                        'red_bans',
                        'red_picks',
                        'red_kill',
                        'red_turret',
                        'red_dragon',
                        'red_baron',
                        'red_gold']).T

# %%
total_df['red_bans'] = total_df['red_bans'].str.replace('stats','')
total_df['red_bans'] = total_df['red_bans'].str.replace(' ','')
total_df['red_picks'] = total_df['red_picks'].str.replace('stats','')
total_df['red_picks'] = total_df['red_picks'].str.replace(' ','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace('stats','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace(' ','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace('stats','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace(' ','')

# %%
total_df.to_csv('GengSummary.csv')

# %%
# 데이터를 가져올 페이지로 이동합니다.
driver.get(league_data_url2)

# %%
# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []
call_name     = []
kill          = []
death         = []
assist        = []
kda           = []
cs            = []
csinteamjg    = []
csinenemyjg   = []
csm           = []
golds         = []
gpm           = []
gold_per      = []
visionscore   = []
ward_placed   = []
ward_destroyed= []
vspm          = []
wpm           = []
vwpm          = []
wcpm          = []
vs_per        = []
Total_damage  = []
dpm           = []
dmg_per       = []
gd15          = []
csd15         = []
xpd15         = []
lvld15        = []
to_dmg_turrets= []
champion      = []

# %%
# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    for num in range(2, 12):
    # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
    
    ## All stat 들어가서 상세 정보 가져오기
    time.sleep(1)
    driver.find_element_by_css_selector('#gameMenu2Toggler > ul > li:nth-child(2) > a').click()
    
    time.sleep(1)
    for num3 in range(2,12):
        c = driver.find_elements_by_css_selector(f'body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table >thead > tr > th:nth-child({num3}) > img ')
        for i2 in c:
            champion.append(i2.get_attribute('alt'))
            
            
    for num2 in range(2, 12):
        call_name.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(1) > td:nth-child({num2})").text.strip())
        
        kill.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(3) > td:nth-child({num2})").text.strip())
        death.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(4) > td:nth-child({num2})").text.strip())
        assist.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(5) > td:nth-child({num2})").text.strip())
        kda.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(6) > td:nth-child({num2})").text.strip())
        cs.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(7) > td:nth-child({num2})").text.strip())
        csinteamjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(8) > td:nth-child({num2})").text.strip())
        csinenemyjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(9) > td:nth-child({num2})").text.strip())
        csm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(10) > td:nth-child({num2})").text.strip())
        golds.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(11) > td:nth-child({num2})").text.strip())
        gpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(12) > td:nth-child({num2})").text.strip())
        gold_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(13) > td:nth-child({num2})").text.strip())
        visionscore.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(14) > td:nth-child({num2})").text.strip())
        ward_placed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(15) > td:nth-child({num2})").text.strip())
        ward_destroyed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(16) > td:nth-child({num2})").text.strip())
        
        vspm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(18) > td:nth-child({num2})").text.strip())
        wpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(19) > td:nth-child({num2})").text.strip())
        vwpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(20) > td:nth-child({num2})").text.strip())
        wcpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(21) > td:nth-child({num2})").text.strip())
        vs_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(22) > td:nth-child({num2})").text.strip())
        Total_damage.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(23) > td:nth-child({num2})").text.strip())
        
        dpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(27) > td:nth-child({num2})").text.strip())
        dmg_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(28) > td:nth-child({num2})").text.strip())
        gd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(36) > td:nth-child({num2})").text.strip())
        csd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(37) > td:nth-child({num2})").text.strip())
        xpd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(38) > td:nth-child({num2})").text.strip())
        lvld15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(39) > td:nth-child({num2})").text.strip())
        to_dmg_turrets.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(40) > td:nth-child({num2})").text.strip())

    

    
    time.sleep(1)
    
    
    driver.back()
    time.sleep(1)
    
    driver.back()
    time.sleep(1)

# %%
total_df = pd.DataFrame([client_version,
                         gametime,
                            blue_teamname,
                            blue_result,
                         red_teamname,
                         red_result,
                            call_name,
                             champion,
                            kill,
                            death,
                            assist,
                            kda,
                            cs,
                            csinteamjg,
                            csinenemyjg,
                            csm,
                            golds,
                            gpm,
                            gold_per,
                            visionscore,
                            ward_placed,
                            ward_destroyed,
                            vspm,
                            wpm,
                            vwpm,
                            wcpm,
                            vs_per,
                            Total_damage,
                            dpm,
                            dmg_per,
                            gd15,
                            csd15,
                            xpd15,
                            lvld15,
                            to_dmg_turrets],
                        index = ['client_version',
                         'gametime',
                            'blue_teamname',
                            'blue_result',
                         'red_teamname',
                         'red_result',
                            'call_name',
                            'kill',
                            'death',
                            'assist',
                            'kda',
                            'cs',
                            'csinteamjg',
                            'csinenemyjg',
                            'csm',
                            'golds',
                            'gpm',
                            'gold_per',
                            'visionscore',
                            'ward_placed',
                            'ward_destroyed',
                            'vspm',
                            'wpm',
                            'vwpm',
                            'wcpm',
                            'vs_per',
                            'Total_damage',
                            'dpm',
                            'dmg_per',
                            'gd15',
                            'csd15',
                            'xpd15',
                            'lvld15',
                            'to_dmg_turrets']).T

# %%
total_df.to_csv('GengData_ps.csv')

# %%
# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []

blue_kill     = []
blue_turret   = []
blue_dragon   = []
blue_baron    = []
blue_gold     = []
blue_bans      = []
blue_picks     = []

red_kill      = []
red_turret    = []
red_dragon    = []
red_baron     = []
red_gold      = []
red_bans       = []
red_picks      = []

# %%
# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    blue_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    blue_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')

    red_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    red_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')
    
    for i in blue_ban:
        blue_bans.append(i.get_attribute('title'))
    for i2 in blue_pick:
        blue_picks.append(i2.get_attribute('title'))
    for i3 in red_ban:
        red_bans.append(i3.get_attribute('title'))
    for i4 in red_pick:
        red_picks.append(i4.get_attribute('title'))


        # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
       # 블루팀 정보
        blue_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        blue_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        blue_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        blue_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        blue_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(5) > span').text.strip())

        # 레드팀 정보
        red_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        red_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        red_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        red_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        red_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(5) > span').text.strip())
    
    driver.back()
    time.sleep(1)

# %%
total_df = pd.DataFrame([client_version,
                        blue_teamname,
                         blue_result,
                        red_teamname,
                         red_result,
                        gametime,
                        # 블루팀
                        blue_bans,
                        blue_picks,
                        blue_kill,
                        blue_turret,
                        blue_dragon,
                        blue_baron,
                        blue_gold,
                        # 레드팀
                        red_bans,
                        red_picks,
                        red_kill,
                        red_turret,
                        red_dragon,
                        red_baron,
                        red_gold],
                        index = ['client_version',
                        'blue_teamname',
                         'blue_result',
                        'red_teamname',
                         'red_result',
                        'gametime',
                        # 블루팀
                        'blue_bans',
                        'blue_picks',
                        'blue_kill',
                        'blue_turret',
                        'blue_dragon',
                        'blue_baron',
                        'blue_gold',
                        # 레드팀
                        'red_bans',
                        'red_picks',
                        'red_kill',
                        'red_turret',
                        'red_dragon',
                        'red_baron',
                        'red_gold']).T

# %%
total_df['red_bans'] = total_df['red_bans'].str.replace('stats','')
total_df['red_bans'] = total_df['red_bans'].str.replace(' ','')
total_df['red_picks'] = total_df['red_picks'].str.replace('stats','')
total_df['red_picks'] = total_df['red_picks'].str.replace(' ','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace('stats','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace(' ','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace('stats','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace(' ','')

# %%
total_df.to_csv('GengSummary_ps.csv')

# %% [markdown]
# ## 모든 데이터

# %%
# 우리가 데이터를 가져올 웹 페이지입니다.
league_data_url = 'https://gol.gg/teams/team-matchlist/1126/split-ALL/tournament-LCK%20Spring%202021/'
league_data_url2 = 'https://gol.gg/teams/team-matchlist/1126/split-ALL/tournament-LCK%20Spring%20Playoffs%202021/'

# selenium이 제어할 chrome을 실행합니다.
# driver = webdriver.Chrome("C:/Users/LUNA/Desktop/OPGG/chromedriver_win32/chromedriver")
driver = webdriver.Chrome("C:/Users/LUNA/Desktop/OPGG/chromedriver_win32/chromedriver", options= options)

# 데이터를 가져올 페이지로 이동합니다.
driver.get(league_data_url)

# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []
call_name     = []
kill          = []
death         = []
assist        = []
kda           = []
cs            = []
csinteamjg    = []
csinenemyjg   = []
csm           = []
golds         = []
gpm           = []
gold_per      = []
visionscore   = []
ward_placed   = []
ward_destroyed= []
vspm          = []
wpm           = []
vwpm          = []
wcpm          = []
vs_per        = []
Total_damage  = []
dpm           = []
dmg_per       = []
gd15          = []
csd15         = []
xpd15         = []
lvld15        = []
to_dmg_turrets= []
champion      = []

# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    for num in range(2, 12):
    # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
    
    ## All stat 들어가서 상세 정보 가져오기
    time.sleep(1)
    driver.find_element_by_css_selector('#gameMenu2Toggler > ul > li:nth-child(2) > a').click()
    
    time.sleep(1)
    for num3 in range(2,12):
        c = driver.find_elements_by_css_selector(f'body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table >thead > tr > th:nth-child({num3}) > img ')
        for i2 in c:
            champion.append(i2.get_attribute('alt'))
            
            
    for num2 in range(2, 12):
        call_name.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(1) > td:nth-child({num2})").text.strip())
        
        kill.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(3) > td:nth-child({num2})").text.strip())
        death.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(4) > td:nth-child({num2})").text.strip())
        assist.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(5) > td:nth-child({num2})").text.strip())
        kda.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(6) > td:nth-child({num2})").text.strip())
        cs.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(7) > td:nth-child({num2})").text.strip())
        csinteamjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(8) > td:nth-child({num2})").text.strip())
        csinenemyjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(9) > td:nth-child({num2})").text.strip())
        csm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(10) > td:nth-child({num2})").text.strip())
        golds.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(11) > td:nth-child({num2})").text.strip())
        gpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(12) > td:nth-child({num2})").text.strip())
        gold_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(13) > td:nth-child({num2})").text.strip())
        visionscore.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(14) > td:nth-child({num2})").text.strip())
        ward_placed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(15) > td:nth-child({num2})").text.strip())
        ward_destroyed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(16) > td:nth-child({num2})").text.strip())
        
        vspm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(18) > td:nth-child({num2})").text.strip())
        wpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(19) > td:nth-child({num2})").text.strip())
        vwpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(20) > td:nth-child({num2})").text.strip())
        wcpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(21) > td:nth-child({num2})").text.strip())
        vs_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(22) > td:nth-child({num2})").text.strip())
        Total_damage.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(23) > td:nth-child({num2})").text.strip())
        
        dpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(27) > td:nth-child({num2})").text.strip())
        dmg_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(28) > td:nth-child({num2})").text.strip())
        gd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(36) > td:nth-child({num2})").text.strip())
        csd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(37) > td:nth-child({num2})").text.strip())
        xpd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(38) > td:nth-child({num2})").text.strip())
        lvld15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(39) > td:nth-child({num2})").text.strip())
        to_dmg_turrets.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(40) > td:nth-child({num2})").text.strip())

    

    
    time.sleep(1)
    
    
    driver.back()
    time.sleep(1)
    
    driver.back()
    time.sleep(1)

total_df = pd.DataFrame([client_version,
                         gametime,
                            blue_teamname,
                            blue_result,
                         red_teamname,
                         red_result,
                            call_name,
                         champion,
                            kill,
                            death,
                            assist,
                            kda,
                            cs,
                            csinteamjg,
                            csinenemyjg,
                            csm,
                            golds,
                            gpm,
                            gold_per,
                            visionscore,
                            ward_placed,
                            ward_destroyed,
                            vspm,
                            wpm,
                            vwpm,
                            wcpm,
                            vs_per,
                            Total_damage,
                            dpm,
                            dmg_per,
                            gd15,
                            csd15,
                            xpd15,
                            lvld15,
                            to_dmg_turrets],
                        index = ['client_version',
                         'gametime',
                            'blue_teamname',
                            'blue_result',
                         'red_teamname',
                         'red_result',
                            'call_name',
                                     'champion',
                            'kill',
                            'death',
                            'assist',
                            'kda',
                            'cs',
                            'csinteamjg',
                            'csinenemyjg',
                            'csm',
                            'golds',
                            'gpm',
                            'gold_per',
                            'visionscore',
                            'ward_placed',
                            'ward_destroyed',
                            'vspm',
                            'wpm',
                            'vwpm',
                            'wcpm',
                            'vs_per',
                            'Total_damage',
                            'dpm',
                            'dmg_per',
                            'gd15',
                            'csd15',
                            'xpd15',
                            'lvld15',
                            'to_dmg_turrets']).T

total_df.to_csv('data_Gen DK/GengData.csv')

## summary

# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []

blue_kill     = []
blue_turret   = []
blue_dragon   = []
blue_baron    = []
blue_gold     = []
blue_bans      = []
blue_picks     = []

red_kill      = []
red_turret    = []
red_dragon    = []
red_baron     = []
red_gold      = []
red_bans       = []
red_picks      = []


# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    blue_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    blue_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')

    red_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    red_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')
    
    for i in blue_ban:
        blue_bans.append(i.get_attribute('title'))
    for i2 in blue_pick:
        blue_picks.append(i2.get_attribute('title'))
    for i3 in red_ban:
        red_bans.append(i3.get_attribute('title'))
    for i4 in red_pick:
        red_picks.append(i4.get_attribute('title'))


        # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
       # 블루팀 정보
        blue_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        blue_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        blue_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        blue_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        blue_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(5) > span').text.strip())

        # 레드팀 정보
        red_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        red_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        red_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        red_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        red_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(5) > span').text.strip())
    
    driver.back()
    time.sleep(1)

total_df = pd.DataFrame([client_version,
                        blue_teamname,
                         blue_result,
                        red_teamname,
                         red_result,
                        gametime,
                        # 블루팀
                        blue_bans,
                        blue_picks,
                        blue_kill,
                        blue_turret,
                        blue_dragon,
                        blue_baron,
                        blue_gold,
                        # 레드팀
                        red_bans,
                        red_picks,
                        red_kill,
                        red_turret,
                        red_dragon,
                        red_baron,
                        red_gold],
                        index = ['client_version',
                        'blue_teamname',
                         'blue_result',
                        'red_teamname',
                         'red_result',
                        'gametime',
                        # 블루팀
                        'blue_bans',
                        'blue_picks',
                        'blue_kill',
                        'blue_turret',
                        'blue_dragon',
                        'blue_baron',
                        'blue_gold',
                        # 레드팀
                        'red_bans',
                        'red_picks',
                        'red_kill',
                        'red_turret',
                        'red_dragon',
                        'red_baron',
                        'red_gold']).T

total_df['red_bans'] = total_df['red_bans'].str.replace('stats','')
total_df['red_bans'] = total_df['red_bans'].str.replace(' ','')
total_df['red_picks'] = total_df['red_picks'].str.replace('stats','')
total_df['red_picks'] = total_df['red_picks'].str.replace(' ','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace('stats','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace(' ','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace('stats','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace(' ','')

total_df.to_csv('data_Gen DK/GengSummary.csv')

# 데이터를 가져올 페이지로 이동합니다.
driver.get(league_data_url2)

# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []
call_name     = []
kill          = []
death         = []
assist        = []
kda           = []
cs            = []
csinteamjg    = []
csinenemyjg   = []
csm           = []
golds         = []
gpm           = []
gold_per      = []
visionscore   = []
ward_placed   = []
ward_destroyed= []
vspm          = []
wpm           = []
vwpm          = []
wcpm          = []
vs_per        = []
Total_damage  = []
dpm           = []
dmg_per       = []
gd15          = []
csd15         = []
xpd15         = []
lvld15        = []
to_dmg_turrets= []
champion      = []

# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    for num in range(2, 12):
    # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
    
    ## All stat 들어가서 상세 정보 가져오기
    time.sleep(1)
    driver.find_element_by_css_selector('#gameMenu2Toggler > ul > li:nth-child(2) > a').click()
    
    time.sleep(1)
    for num3 in range(2,12):
        c = driver.find_elements_by_css_selector(f'body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table >thead > tr > th:nth-child({num3}) > img ')
        for i2 in c:
            champion.append(i2.get_attribute('alt'))
            
            
    for num2 in range(2, 12):
        call_name.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(1) > td:nth-child({num2})").text.strip())
        
        kill.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(3) > td:nth-child({num2})").text.strip())
        death.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(4) > td:nth-child({num2})").text.strip())
        assist.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(5) > td:nth-child({num2})").text.strip())
        kda.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(6) > td:nth-child({num2})").text.strip())
        cs.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(7) > td:nth-child({num2})").text.strip())
        csinteamjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(8) > td:nth-child({num2})").text.strip())
        csinenemyjg.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(9) > td:nth-child({num2})").text.strip())
        csm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(10) > td:nth-child({num2})").text.strip())
        golds.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(11) > td:nth-child({num2})").text.strip())
        gpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(12) > td:nth-child({num2})").text.strip())
        gold_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(13) > td:nth-child({num2})").text.strip())
        visionscore.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(14) > td:nth-child({num2})").text.strip())
        ward_placed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(15) > td:nth-child({num2})").text.strip())
        ward_destroyed.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(16) > td:nth-child({num2})").text.strip())
        
        vspm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(18) > td:nth-child({num2})").text.strip())
        wpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(19) > td:nth-child({num2})").text.strip())
        vwpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(20) > td:nth-child({num2})").text.strip())
        wcpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(21) > td:nth-child({num2})").text.strip())
        vs_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(22) > td:nth-child({num2})").text.strip())
        Total_damage.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(23) > td:nth-child({num2})").text.strip())
        
        dpm.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(27) > td:nth-child({num2})").text.strip())
        dmg_per.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(28) > td:nth-child({num2})").text.strip())
        gd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(36) > td:nth-child({num2})").text.strip())
        csd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(37) > td:nth-child({num2})").text.strip())
        xpd15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(38) > td:nth-child({num2})").text.strip())
        lvld15.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(39) > td:nth-child({num2})").text.strip())
        to_dmg_turrets.append(driver.find_element_by_css_selector(f"body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > table > tbody > tr:nth-child(40) > td:nth-child({num2})").text.strip())

    

    
    time.sleep(1)
    
    
    driver.back()
    time.sleep(1)
    
    driver.back()
    time.sleep(1)

total_df = pd.DataFrame([client_version,
                         gametime,
                            blue_teamname,
                            blue_result,
                         red_teamname,
                         red_result,
                            call_name,
                         champion,
                            kill,
                            death,
                            assist,
                            kda,
                            cs,
                            csinteamjg,
                            csinenemyjg,
                            csm,
                            golds,
                            gpm,
                            gold_per,
                            visionscore,
                            ward_placed,
                            ward_destroyed,
                            vspm,
                            wpm,
                            vwpm,
                            wcpm,
                            vs_per,
                            Total_damage,
                            dpm,
                            dmg_per,
                            gd15,
                            csd15,
                            xpd15,
                            lvld15,
                            to_dmg_turrets],
                        index = ['client_version',
                         'gametime',
                            'blue_teamname',
                            'blue_result',
                         'red_teamname',
                         'red_result',
                            'call_name',
                                 'champion',
                            'kill',
                            'death',
                            'assist',
                            'kda',
                            'cs',
                            'csinteamjg',
                            'csinenemyjg',
                            'csm',
                            'golds',
                            'gpm',
                            'gold_per',
                            'visionscore',
                            'ward_placed',
                            'ward_destroyed',
                            'vspm',
                            'wpm',
                            'vwpm',
                            'wcpm',
                            'vs_per',
                            'Total_damage',
                            'dpm',
                            'dmg_per',
                            'gd15',
                            'csd15',
                            'xpd15',
                            'lvld15',
                            'to_dmg_turrets']).T

total_df.to_csv('data_Gen DK/GengData_ps.csv')

# 결과가 들어갈 리스트
blue_teamname = []
red_teamname  = []
gametime      = []
client_version= []
blue_result   = []
red_result    = []

blue_kill     = []
blue_turret   = []
blue_dragon   = []
blue_baron    = []
blue_gold     = []
blue_bans      = []
blue_picks     = []

red_kill      = []
red_turret    = []
red_dragon    = []
red_baron     = []
red_gold      = []
red_bans       = []
red_picks      = []


# 일단 경기 결과 다 클릭하는거 체크
time.sleep(1)

# 경기 수만큼 길이 설정 
a= driver.find_elements_by_css_selector('body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr')

for i in range(1,len(a)):
    time.sleep(1)
    # 경기 다 한번씩 클릭해서 상세 정보 들어가기
    driver.find_element_by_css_selector(f'body > div > main > div:nth-child(7) > div > div.row.rowbreak.fond-main-cadre > div > div > div > table > tbody > tr:nth-child({i}) > td:nth-child(14) > a').click()
    time.sleep(1)
    
    blue_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    blue_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')

    red_ban  = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(1) > div.col-10 > a')
    red_pick = driver.find_elements_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > div > div:nth-child(2) > div.col-10 > a')
    
    for i in blue_ban:
        blue_bans.append(i.get_attribute('title'))
    for i2 in blue_pick:
        blue_picks.append(i2.get_attribute('title'))
    for i3 in red_ban:
        red_bans.append(i3.get_attribute('title'))
    for i4 in red_pick:
        red_picks.append(i4.get_attribute('title'))


        # 요약본에서 정보 가져오기
        gametime.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-6.text-center > h1').text.strip())
        blue_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div > a').text.strip())
        blue_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        red_teamname.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div > a').text.strip())
        red_result.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div.row.rowbreak.pb-3 > div').text.strip()[-4:])
        client_version.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(1) > div.col-3.text-right').text.strip())
       # 블루팀 정보
        blue_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        blue_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        blue_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        blue_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        blue_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > div:nth-child(5) > span').text.strip())

        # 레드팀 정보
        red_kill.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(1) > span').text.strip())
        red_turret.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > span').text.strip())
        red_dragon.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(3) > span').text.strip())
        red_baron.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(4) > span').text.strip())
        red_gold.append(driver.find_element_by_css_selector('body > div > main > div:nth-child(4) > div > div:nth-child(4) > div > div > div > div:nth-child(1) > div > div > div:nth-child(2) > div:nth-child(2) > div:nth-child(2) > div:nth-child(5) > span').text.strip())
    
    driver.back()
    time.sleep(1)

total_df = pd.DataFrame([client_version,
                        blue_teamname,
                         blue_result,
                        red_teamname,
                         red_result,
                        gametime,
                        # 블루팀
                        blue_bans,
                        blue_picks,
                        blue_kill,
                        blue_turret,
                        blue_dragon,
                        blue_baron,
                        blue_gold,
                        # 레드팀
                        red_bans,
                        red_picks,
                        red_kill,
                        red_turret,
                        red_dragon,
                        red_baron,
                        red_gold],
                        index = ['client_version',
                        'blue_teamname',
                         'blue_result',
                        'red_teamname',
                         'red_result',
                        'gametime',
                        # 블루팀
                        'blue_bans',
                        'blue_picks',
                        'blue_kill',
                        'blue_turret',
                        'blue_dragon',
                        'blue_baron',
                        'blue_gold',
                        # 레드팀
                        'red_bans',
                        'red_picks',
                        'red_kill',
                        'red_turret',
                        'red_dragon',
                        'red_baron',
                        'red_gold']).T

total_df['red_bans'] = total_df['red_bans'].str.replace('stats','')
total_df['red_bans'] = total_df['red_bans'].str.replace(' ','')
total_df['red_picks'] = total_df['red_picks'].str.replace('stats','')
total_df['red_picks'] = total_df['red_picks'].str.replace(' ','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace('stats','')
total_df['blue_bans'] = total_df['blue_bans'].str.replace(' ','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace('stats','')
total_df['blue_picks'] = total_df['blue_picks'].str.replace(' ','')

total_df.to_csv('data_Gen DK/GengSummary_ps.csv')
